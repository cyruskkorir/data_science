# %%
import pandas as pd

df = pd.read_csv('Assignment.csv')
df
# Out:
#                                               body_text           id  \
# 0     Cupidatat consectetur magna ex ipsum ut laboru...  43022520334
# 1     Detected intent: nutrition (confidence: 0.9767...  43022520336
# 2     Detected intent: pain (confidence: 0.976750003...  43022524893
# 3     Detected intent: pregnancy_condition (confiden...  43022524894
# 4     Detected intent: pain (confidence: 0.878675000...  43022545487
# ...                                                 ...          ...
# 1100  Detected intent: nutrition (confidence: 0.3400...  43052346575
# 1101  Detected intent: survey_response (confidence: ...  43052554092
# 1102  Detected intent: baby_condition (confidence: 0...  43052346587
# 1103  Detected intent: breastfeeding (confidence: 0....  43052346594
# 1104  Detected intent: qsurvey_positive (confidence:...  43052512785
#
#       incoming  ticket_id      user_id           created_at  Unnamed: 6  \
# ...

# %%
unique_tkt = df.drop_duplicates(subset='ticket_id')
unique_tkt
# Out:
#                                               body_text           id  \
# 0     Cupidatat consectetur magna ex ipsum ut laboru...  43022520334
# 2     Detected intent: pain (confidence: 0.976750003...  43022524893
# 7     Detected intent: survey_response (confidence: ...  43022525662
# 17    Detected intent: fetal_movement (confidence: 0...  43022549306
# 20    Detected intent: qsurvey_positive (confidence:...  43022935507
# ...                                                 ...          ...
# 1092  Detected intent: survey_response (confidence: ...  43051218458
# 1094  Detected intent: survey_response (confidence: ...  43051227690
# 1096  Detected intent: nutrition (confidence: 0.3400...  43051515274
# 1098  Detected intent: qsurvey_positive (confidence:...  43052347762
# 1102  Detected intent: baby_condition (confidence: 0...  43052346587
#
#       incoming  ticket_id      user_id           created_at  Unnamed: 6  \
# ...

# %%
unique_.isna().sum()

# remove empty values
=unique_tkt.dropna(axis=1)
